# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading the dataset

# %%
data = pd.read_csv("C:/Users/sravy/OneDrive/Documents/MSISOM/Sample Practice  Proj/Hotel Booking Demand EDA/hotel_bookings.csv")

# %% [markdown]
# ## Exploratory Data Analysis and Data Cleaning

# %%
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
data.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
data.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# To see total no of col and rows.
data.shape
# Out:
# (119390, 32)

# %%
#To see all the columns
data.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
#To see all the data types present in the data set
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
#changing reservation_status_date col to date time format.
data["reservation_status_date"] = pd.to_datetime(data["reservation_status_date"])
data["reservation_status_date"]
# Out:
# 0        2015-07-01
# 1        2015-07-01
# 2        2015-07-02
# 3        2015-07-02
# 4        2015-07-03
#             ...
# 119385   2017-09-06
# 119386   2017-09-07
# 119387   2017-09-07
# 119388   2017-09-07
# 119389   2017-09-07
# Name: reservation_status_date, Length: 119390, dtype: datetime64[ns]

# %%
#lets get the summary of dataset.
data.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
#now lets see the onject col summary stats
data.describe(include = "object")
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status
# count        119390        119390             119390
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         104641         89613              75166

# %%
for col in data.describe(include = "object").columns:
 print(col)
 print(data[col].unique())
#adding seperation line to make it clear.
 print("-"*100)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# ----------------------------------------------------------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# ----------------------------------------------------------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# ----------------------------------------------------------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
# ...

# %%
data.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
#removing the col that has missing values from dataset since they have no use and larger data is harder to handle.
data.dropna(inplace = True)

# %%
data.describe()
# Out:
#        is_canceled   lead_time  arrival_date_year  arrival_date_week_number  \
# count   217.000000  217.000000         217.000000                217.000000
# mean      0.078341   40.520737        2015.465438                 38.198157
# std       0.269329   61.748375           0.720053                 12.890292
# min       0.000000    0.000000        2015.000000                  1.000000
# 25%       0.000000   12.000000        2015.000000                 33.000000
# 50%       0.000000   27.000000        2015.000000                 45.000000
# 75%       0.000000   36.000000        2016.000000                 46.000000
# max       1.000000  364.000000        2017.000000                 53.000000
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# count                 217.000000                217.00000
# mean                   10.824885                  1.56682
# std                     7.582065                  1.49270
# ...

# %%
data.head()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 2392  Resort Hotel            0          6               2015
# 2697  Resort Hotel            0         24               2015
# 2867  Resort Hotel            0         24               2015
# 2877  Resort Hotel            0         24               2015
# 2878  Resort Hotel            0         24               2015
#
#      arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 2392            October                        42                         11
# 2697            October                        44                         26
# 2867           November                        45                          3
# 2877           November                        45                          3
# 2878           November                        45                          3
#
#       stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# ...

# %%
data['adr'].plot(kind = "box")
# Out:
# <Axes: >

# %%
data[['adr','children','lead_time']].plot(kind = "box")
# Out:
# <Axes: >

# %%
data = data[data['adr']<5000]
data.head(5)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 2392  Resort Hotel            0          6               2015
# 2697  Resort Hotel            0         24               2015
# 2867  Resort Hotel            0         24               2015
# 2877  Resort Hotel            0         24               2015
# 2878  Resort Hotel            0         24               2015
#
#      arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 2392            October                        42                         11
# 2697            October                        44                         26
# 2867           November                        45                          3
# 2877           November                        45                          3
# 2878           November                        45                          3
#
#       stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# ...

# %% [markdown]
# ## Data  Analysis and Visualization.

# %%
cancelled_perc = data['is_canceled'].value_counts()
cancelled_perc
plt.figure(figsize = (4,3))
plt.title("Reservation status count")
plt.bar(["Not cancelled", "Cancelled"], data['is_canceled'].value_counts())
# Out:
# <BarContainer object of 2 artists>

# %%
plt.figure(figsize = (4,3))
ax1 = sns.countplot(x = "hotel", hue = "is_canceled", data = data,palette = "Blues" )
legend_labels,_ = ax1.get_legend_handles_labels()
ax1.legend(bbox_to_anchor=[2,1])
plt.title("Reservation status in different hotels", size =20)
plt.xlabel("Hotel")
plt.ylabel("No of reservations")
plt.legend(["not cancelled", "is_cancelled"])
plt.show()

# %%
resort_hotel = data[data["hotel"] == "Resort Hotel"]
resort_hotel["is_canceled"].value_counts(normalize = True)
resort_hotel.head(2)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 2392  Resort Hotel            0          6               2015
# 2697  Resort Hotel            0         24               2015
#
#      arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 2392            October                        42                         11
# 2697            October                        44                         26
#
#       stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 2392                        2                     0       2  ...
# 2697                        7                    15       1  ...
#
#       deposit_type  agent company days_in_waiting_list    customer_type   adr  \
# 2392    No Deposit  240.0   113.0                    0        Transient  82.0
# 2697    No Deposit  185.0   281.0                    0  Transient-Party  52.2
#
#       required_car_parking_spaces  total_of_special_requests  \
# ...

# %%
city_hotel = data[data["hotel"] == "City Hotel"]
city_hotel["is_canceled"].value_counts(normalize = True)
city_hotel.head(2)
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 40920  City Hotel            0          0               2015
# 40966  City Hotel            0          1               2015
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 40920             August                        33                          9
# 40966             August                        33                         10
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 40920                        1                     0       2  ...
# 40966                        1                     1       2  ...
#
#        deposit_type  agent company days_in_waiting_list customer_type    adr  \
# 40920    No Deposit    9.0     9.0                    0     Transient  105.0
# 40966    No Deposit    9.0     9.0                    0      Contract  105.0
#
#        required_car_parking_spaces  total_of_special_requests  \
# ...

# %%
#resort_hotel.head(2)
resort_hotel = resort_hotel.groupby("reservation_status_date")[["adr"]].mean()
city_hotel = city_hotel.groupby("reservation_status_date")[["adr"]].mean()
resort_hotel.head(2)
city_hotel.head(2)
# Out:
#                            adr
# reservation_status_date
# 2015-08-09               105.0
# 2015-08-10               105.0

# %%
plt.figure(figsize = (20,8))
plt.title("Average Daily Rate in City and Resort Hotels", fontsize= 30)
plt.plot(resort_hotel.index, resort_hotel['adr'], label = "Resort Hotel")
plt.plot(city_hotel.index, city_hotel['adr'], label = "City Hotel")
plt.legend(["resort hotel", "city hotel"])
plt.show()

# %%
data["month"] = data["reservation_status_date"].dt.month
plt.figure(figsize = (16,8))
plt.title("Reservation Status Per Month", fontsize= 30)
ax1 = sns.countplot(x = "month", hue = "is_canceled", data = data)
plt.ylabel("No of reservations")
plt.legend(["not cancelled", "is_cancelled"])
plt.show()

# %%
plt.figure(figsize=(16, 8))
plt.title("ADR per month", fontsize=30)
sns.barplot(x="month", y="adr", data=data[data["is_canceled"] == 1].groupby("month")[["adr"]].sum().reset_index())
plt.show()

# %%
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 2392  Resort Hotel            0          6               2015
# 2697  Resort Hotel            0         24               2015
#
#      arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 2392            October                        42                         11
# 2697            October                        44                         26
#
#       stays_in_weekend_nights  stays_in_week_nights  adults  ...  agent  \
# 2392                        2                     0       2  ...  240.0
# 2697                        7                    15       1  ...  185.0
#
#       company days_in_waiting_list    customer_type   adr  \
# 2392    113.0                    0        Transient  82.0
# 2697    281.0                    0  Transient-Party  52.2
#
#      required_car_parking_spaces  total_of_special_requests  \
# 2392                           1                          1
# ...

# %%
cancelled_data = data[data["is_canceled"] == 1]
cancelled_data 
#top_10_country = cancelled_data['country'].value-counts()[:10]
#plt.figure(figsize=(8, 8))
#plt.title("Top 10 Countires With Reservations Cancelled")
#plt.pie(top_10_country, autopct = "%.2f",labels = top_10_country.index)
#plt.show()
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 2941   Resort Hotel            1         36               2015
# 2971   Resort Hotel            1         37               2015
# 2983   Resort Hotel            1         38               2015
# 2984   Resort Hotel            1         38               2015
# 2988   Resort Hotel            1         30               2015
# 3004   Resort Hotel            1         40               2015
# 3050   Resort Hotel            1         33               2015
# 3057   Resort Hotel            1          3               2015
# 3064   Resort Hotel            1         41               2015
# 3065   Resort Hotel            1         41               2015
# 3066   Resort Hotel            1         41               2015
# 3067   Resort Hotel            1         41               2015
# 5700   Resort Hotel            1          7               2016
# 12237  Resort Hotel            1        114               2017
# ...

# %%
 cancelled_data.head(2)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 2941  Resort Hotel            1         36               2015
# 2971  Resort Hotel            1         37               2015
#
#      arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 2941           November                        45                          7
# 2971           November                        46                          8
#
#       stays_in_weekend_nights  stays_in_week_nights  adults  ...  agent  \
# 2941                        2                     6       1  ...  185.0
# 2971                        2                     5       1  ...  185.0
#
#       company days_in_waiting_list    customer_type   adr  \
# 2941    281.0                    0  Transient-Party  36.0
# 2971    281.0                    0  Transient-Party  36.0
#
#      required_car_parking_spaces  total_of_special_requests  \
# 2941                           0                          0
# ...
